# %%
import metview as mv

import numpy as np
import xarray as xr

# Libraries for plotting and visualising data
import matplotlib.path as mpath
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature#
import os

# %%
alt_file_tp="/media/cap/7fed51bd-a88e-4971-9656-d617655b6312/data/CARRA/means_comparison/TP/TP-alt-01-2023.nc"
orig_file_tp="/media/cap/7fed51bd-a88e-4971-9656-d617655b6312/data/CARRA/means_comparison/TP/monthly_mean_accum_no-ar-cw_fc_sfc_202301.grib2"

# %%
ds_alt_tp = xr.open_dataset(alt_file_tp)
ds_orig_tp = xr.open_dataset(orig_file_tp)

# %%
ds_alt_tp
# Out:
# <xarray.Dataset>
# Dimensions:  (LAT: 1269, LON: 1069)
# Dimensions without coordinates: LAT, LON
# Data variables:
#     lat      (LAT, LON) float32 ...
#     lon      (LAT, LON) float32 ...
#     TP       (LAT, LON) float32 ...
# Attributes:
#     description:           Statistics for total precipitation
#     typeOfStatistics:      monthly_mean_full_day
#     numberOfDatasetsUsed:  0

# %%
ds_orig_tp["tp"]
# Out:
# <xarray.DataArray 'tp' (y: 1269, x: 1069)>
# [1356561 values with dtype=float32]
# Coordinates:
#     time                 datetime64[ns] ...
#     step                 timedelta64[ns] ...
#     surface              float64 ...
#     latitude             (y, x) float64 ...
#     longitude            (y, x) float64 ...
#     valid_time           datetime64[ns] ...
#     indefiniteSoilDepth  float64 ...
#     nominalTop           float64 ...
# Dimensions without coordinates: y, x
# Attributes: (12/33)
#     GRIB_paramId:                             228228
#     GRIB_dataType:                            fc
#     GRIB_numberOfPoints:                      1356561
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            accum
#     ...                                       ...
#     GRIB_name:                                Total Precipitation
#     GRIB_shortName:                           tp
# ...

# %%
max_val=ds_alt_tp["TP"].max()
min_Val=ds_alt_tp["TP"].min()
levels = np.linspace(0,40,10)
import matplotlib as mpl

cmap = mpl.cm.coolwarm

# %%
ds_alt_tp["TP"].plot.contourf(cmap=cmap,levels=levels)

# %%
ds_orig_tp["tp"].plot.contourf(cmap=cmap,levels=levels)

# %%
fig = plt.figure(figsize=[12,9])

# %%
alt_file_t2m="/media/cap/7fed51bd-a88e-4971-9656-d617655b6312/data/CARRA/means_comparison/t2m/t2m-alt-01-2023.nc"
orig_file_t2m="/media/cap/7fed51bd-a88e-4971-9656-d617655b6312/data/CARRA/means_comparison/t2m/t2m_carra_20230101.grib2"

# %%
ds_alt_t2m = xr.open_dataset(alt_file_t2m)

# %%
ds_orig_t2m = xr.open_dataset(orig_file_t2m)

# %%
max_val,min_val=ds_orig_t2m["t2m"].max(),ds_orig_t2m["t2m"].min()

# %%
min_val
# Out:
# <xarray.DataArray 't2m' ()>
# array(228.51739502)
# Coordinates:
#     time               datetime64[ns] ...
#     step               timedelta64[ns] ...
#     heightAboveGround  float64 ...
#     valid_time         datetime64[ns] ...

# %%
max_val
# Out:
# <xarray.DataArray 't2m' ()>
# array(281.36407471)
# Coordinates:
#     time               datetime64[ns] ...
#     step               timedelta64[ns] ...
#     heightAboveGround  float64 ...
#     valid_time         datetime64[ns] ...

# %%
ds_alt_t2m
# Out:
# <xarray.Dataset>
# Dimensions:  (LAT: 1269, LON: 1069)
# Dimensions without coordinates: LAT, LON
# Data variables:
#     lat      (LAT, LON) float32 ...
#     lon      (LAT, LON) float32 ...
#     T2M      (LAT, LON) float32 ...
# Attributes:
#     description:           Statistics for T2m
#     typeOfStatistics:      monthly_mean_full_day
#     numberOfDatasetsUsed:  0

# %%
levels = np.linspace(0,220,290)
ds_alt_t2m["T2M"].plot.contourf(cmap=cmap)#,levels=levels)

# %%
ds_orig_t2m["t2m"].plot.contourf(cmap=cmap)
